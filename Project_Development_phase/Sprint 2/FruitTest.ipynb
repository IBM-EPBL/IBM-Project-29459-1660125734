# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
test_dir=r'/content/drive/MyDrive/dataset/fruit-dataset/test'
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
model = tf.keras.models.load_model(r'fruitdata.h5')
test_datagen_1=ImageDataGenerator(rescale=1)
test_generator_1=test_datagen_1.flow_from_directory(
    test_dir,
    target_size=(128,128),
    batch_size=20,
    class_mode='categorical'
)

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
img=image.load_img(r"/content/drive/MyDrive/dataset/fruit-dataset/train/Apple___healthy/023810b0-18e6-4352-9dfa-c2f4c034cda5___RS_HL 7538.JPG")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FD6AA1DAD10>

# %%
img=image.load_img(r"/content/drive/MyDrive/dataset/fruit-dataset/train/Apple___healthy/03109942-bfa2-4728-b375-4f02a95957de___RS_HL 8066.JPG",target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index=['Apple___Black_rot', 'Apple___healthy', 'Corn_(maize)___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Peach___Bacterial_spot', 'Peach___healthy']
index[y[0]]

# %%
model.evaluate(test_generator_1,steps=50)
