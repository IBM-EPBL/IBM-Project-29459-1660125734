# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dir_path = "/content/drive/MyDrive/dataset/fruit-dataset"

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image
import math
classes = os.listdir(dir_path)
print(classes)
# Out:
# ['Apple___Black_rot', '.ipynb_checkpoints', 'Apple___healthy', 'Corn_(maize)___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Peach___Bacterial_spot', 'Peach___healthy']

# %%
dir_path = "/content/drive/MyDrive/dataset/fruit-dataset/train"
classes = os.listdir(dir_path)
print(classes)
# Out:
# ['Corn_(maize)___Northern_Leaf_Blight', 'Peach___Bacterial_spot', 'Peach___healthy', 'Apple___Black_rot', 'Apple___healthy', 'Corn_(maize)___healthy', '.ipynb_checkpoints']

# %%
dir_path = "/content/drive/MyDrive/dataset/fruit-dataset/test"
classes = os.listdir(dir_path)
print(classes)
# Out:
# ['Apple___Black_rot', '.ipynb_checkpoints', 'Apple___healthy', 'Corn_(maize)___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Peach___Bacterial_spot', 'Peach___healthy']

# %%
train = "/content/drive/MyDrive/dataset/fruit-dataset/train" 
test = "/content/drive/MyDrive/dataset/fruit-dataset/test"

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen=ImageDataGenerator(rescale=1./255,zoom_range=0.2,horizontal_flip=True,vertical_flip=False)
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
x_train=train_datagen.flow_from_directory(train,target_size=(128,128),
                                        class_mode='categorical',batch_size=24)
x_test=test_datagen.flow_from_directory(test,target_size=(128,128),
                                        class_mode='categorical',batch_size=24)
# Out:
# Found 3925 images belonging to 7 classes.
# Found 1686 images belonging to 7 classes.

# %%
model=Sequential()

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
model=load_model('/content/drive/MyDrive/dataset/fruit-dataset/fruit.h5')

# %%
img=image.load_img(r"/content/drive/MyDrive/dataset/fruit-dataset/test/Corn_(maize)___Northern_Leaf_Blight/04d8e1d6-766e-4fcc-9bac-42efb9e6ad33___RS_NLB 3620.JPG")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7F53B2C0F990>

# %%
x=image.img_to_array(img)

# %%
img=image.load_img(r"/content/drive/MyDrive/dataset/fruit-dataset/test/Corn_(maize)___Northern_Leaf_Blight/0da79f56-07f6-4494-a5ba-9722919ee8ad___RS_NLB 3962 copy.jpg",target_size=(128,128))
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F53B2BE1550>

# %%
x=image.img_to_array(img)

# %%
x
# Out:
# array([[[130., 118., 132.],
#         [135., 123., 137.],
#         [140., 128., 142.],
#         ...,
#         [ 82.,  62.,  37.],
#         [ 71.,  54.,  26.],
#         [ 76.,  59.,  29.]],
#
#        [[131., 119., 133.],
#         [134., 122., 136.],
#         [128., 116., 130.],
#         ...,
#         [ 90.,  70.,  45.],
#         [109.,  92.,  62.],
#         [ 84.,  67.,  37.]],
#
#        [[127., 115., 129.],
#         [128., 116., 130.],
#         [130., 118., 132.],
#         ...,
#         [ 84.,  64.,  37.],
#         [105.,  88.,  58.],
#         [ 87.,  72.,  39.]],
#
#        ...,
#
#        [[152., 145., 153.],
#         [151., 144., 152.],
#         [159., 152., 160.],
#         ...,
#         [ 38.,  26.,  28.],
#         [ 35.,  23.,  25.],
#         [ 34.,  22.,  24.]],
#
#        [[150., 143., 151.],
#         [161., 154., 162.],
#         [158., 151., 159.],
#         ...,
#         [ 37.,  25.,  27.],
#         [ 35.,  23.,  25.],
# ...

# %%
x=np.expand_dims(x,axis=0)

# %%
y=np.argmax(model.predict(x),axis=1)
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %%
x_train.class_indices
# Out:
# {'.ipynb_checkpoints': 0,
#  'Apple___Black_rot': 1,
#  'Apple___healthy': 2,
#  'Corn_(maize)___Northern_Leaf_Blight': 3,
#  'Corn_(maize)___healthy': 4,
#  'Peach___Bacterial_spot': 5,
#  'Peach___healthy': 6}

# %%
index=['Apple___Black_rot','Apple___healthy','Corn_(maize)___Northern_Leaf_Blight','Corn_(maize)___healthy','Peach___Bacterial_spot','Peach___healthy']

# %%
index[y[0]]
# Out:
# 'Apple___healthy'

# %%
img=image.load_img(r"/content/drive/MyDrive/dataset/fruit-dataset/test/Corn_(maize)___Northern_Leaf_Blight/2e594c45-c4c7-43b1-ab19-100945e7a2a7___RS_NLB 4020 copy 3.jpg",target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index=['Apple___Black_rot','Apple___healthy','Corn_(maize)___Northern_Leaf_Blight','Corn_(maize)___healthy','Peach___Bacterial_spot','Peach___healthy']
index[y[0]]
# Out:
# 1/1 [==============================] - 0s 43ms/step
# 'Peach___Bacterial_spot'

# %%
test_datagen_1=ImageDataGenerator(rescale=1)
test_generator_1=test_datagen_1.flow_from_directory(
    test,
    target_size=(128,128),
    batch_size=20,
    class_mode='categorical'
)
# Out:
# Found 1686 images belonging to 7 classes.
