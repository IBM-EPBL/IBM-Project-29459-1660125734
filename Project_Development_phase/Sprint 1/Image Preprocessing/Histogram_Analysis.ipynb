# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread

# %%
I = imread('/content/drive/MyDrive/dataset/fruit-dataset/test/Corn_(maize)___Northern_Leaf_Blight/0b54aa70-56aa-4329-9e8d-b3c62c893f14___RS_NLB 4689.JPG')
J = imread('/content/drive/MyDrive/dataset/veg-dataset/test-set/Potato___Late_blight/bb4aa884-a811-4229-bfc0-1df1e7330877___RS_LB 5049.JPG')

# %%
plt.figure()
plt.subplot(121), plt.imshow(I)
plt.subplot(122), plt.imshow(J)
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.imshow(np.abs(I[:, :, 0].astype(float) - J[:, :, 0].astype(float)), cmap='gray')
plt.show()

# %%
d = imread('/content/drive/MyDrive/dataset/fruit-dataset/test/Corn_(maize)___Northern_Leaf_Blight/0b54aa70-56aa-4329-9e8d-b3c62c893f14___RS_NLB 4689.JPG')
mask = imread('/content/drive/MyDrive/dataset/veg-dataset/test-set/Potato___Late_blight/bb4aa884-a811-4229-bfc0-1df1e7330877___RS_LB 5049.JPG')

print(np.amin(d), np.amax(d))
print(np.amin(mask), np.amax(mask))
# Out:
# 0 233
# 0 255

# %%
plt.figure(), plt.imshow(mask), plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>,
# ...
#  None)

# %%
mask = mask[:, :, 0]

# %%
maskInv = np.zeros_like(mask)
maskInv[mask == 0] = 255
maskInv[mask == 255] = 0
plt.figure(), plt.imshow(maskInv, cmap='gray'), plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>,
# ...
#  None)
